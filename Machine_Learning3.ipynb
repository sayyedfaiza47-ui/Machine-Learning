# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7da78ca9-5cb0-4587-855d-2f3ffc12d0af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7da78ca9-5cb0-4587-855d-2f3ffc12d0af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Replace 'your_file.csv' with the uploaded file name
Product_data = pd.read_csv('ML-Dataset.csv')
Product_data
# Out:
#                                                   Name                Type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
# ...

# %%
Product_data.head(5)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#    Control Range             Battery Type  Weight    Price  Actual Price  \
# 0             40          Lithium Battery     200   2297.0        4999.0
# 1            300               AA Battery     500  10255.0       11000.0
# 2            102  AA Rechargeable Battery     150   1994.0        5999.0
# 3             50          Lithium Battery     150   2455.0        4999.0
# 4            200          Lithium Battery     200   4998.0        5999.0
#
#    Discount (%)
# 0          54.0
# 1           6.0
# 2          66.0
# 3          50.0
# ...

# %%
Product_data.tail(3)
# Out:
#                                                   Name                Type  \
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#      Control Range     Battery Type  Weight   Price  Actual Price  \
# 818            102  Lithium Battery     400  1799.0        6999.0
# 819             60  Lithium Battery     250  2799.0        5999.0
# 820            100  Lithium Battery     300  2705.0        8999.0
#
#      Discount (%)
# 818          74.0
# 819          53.0
# 820          69.0

# %%
Product_data.shape
# Out:
# (821, 8)

# %%
print("number of rows = ",Product_data.shape[0])
# Out:
# number of rows =  821

# %%
print("number of columns = ",Product_data.shape[0])
# Out:
# number of columns =  821

# %%
Product_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
Product_data.dtypes
# Out:
# Name              object
# Type              object
# Control Range      int64
# Battery Type      object
# Weight             int64
# Price            float64
# Actual Price     float64
# Discount (%)     float64
# dtype: object

# %%
Product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           821 non-null    object
#  1   Type           821 non-null    object
#  2   Control Range  821 non-null    int64
#  3   Battery Type   821 non-null    object
#  4   Weight         821 non-null    int64
#  5   Price          813 non-null    float64
#  6   Actual Price   813 non-null    float64
#  7   Discount (%)   810 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 51.4+ KB

# %%
Product_data.head(2)
# Out:
#                                                 Name        Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...  Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...  Mini Drone
#
#    Control Range     Battery Type  Weight    Price  Actual Price  Discount (%)
# 0             40  Lithium Battery     200   2297.0        4999.0          54.0
# 1            300       AA Battery     500  10255.0       11000.0           6.0

# %%
Product_tab1 = Product_data[['Name','Type','Battery Type']]
Product_tab1.head(3)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
#
#               Battery Type
# 0          Lithium Battery
# 1               AA Battery
# 2  AA Rechargeable Battery

# %%
Product_tab3 = Product_data.drop(columns=['Name','Type'], axis = 1)
Product_tab3
# Out:
#      Control Range             Battery Type  Weight    Price  Actual Price  \
# 0               40          Lithium Battery     200   2297.0        4999.0
# 1              300               AA Battery     500  10255.0       11000.0
# 2              102  AA Rechargeable Battery     150   1994.0        5999.0
# 3               50          Lithium Battery     150   2455.0        4999.0
# 4              200          Lithium Battery     200   4998.0        5999.0
# ..             ...                      ...     ...      ...           ...
# 816             60          Lithium Battery     250   2244.0        8999.0
# 817            100          Lithium Battery     350   2447.0        4999.0
# 818            102          Lithium Battery     400   1799.0        6999.0
# 819             60          Lithium Battery     250   2799.0        5999.0
# 820            100          Lithium Battery     300   2705.0        8999.0
#
#      Discount (%)
# 0            54.0
# 1             6.0
# ...

# %%
Product_tab3['Dataset']= 'Product_Dataset'
Product_tab3
# Out:
#      Control Range             Battery Type  Weight    Price  Actual Price  \
# 0               40          Lithium Battery     200   2297.0        4999.0
# 1              300               AA Battery     500  10255.0       11000.0
# 2              102  AA Rechargeable Battery     150   1994.0        5999.0
# 3               50          Lithium Battery     150   2455.0        4999.0
# 4              200          Lithium Battery     200   4998.0        5999.0
# ..             ...                      ...     ...      ...           ...
# 816             60          Lithium Battery     250   2244.0        8999.0
# 817            100          Lithium Battery     350   2447.0        4999.0
# 818            102          Lithium Battery     400   1799.0        6999.0
# 819             60          Lithium Battery     250   2799.0        5999.0
# 820            100          Lithium Battery     300   2705.0        8999.0
#
#      Discount (%)          Dataset
# ...

# %%
Product_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
col_dict = {'Name' : 'name',
           'Type' : 'type',
           'Control Range' : 'Control_Range',
            'Battery_Type' : 'Battery_Type',
           'Actual Price' : 'Actual_Price' }

# %%
Product_data = Product_data.rename(columns = col_dict)
Product_data.head(5)
# Out:
#                                                 name                type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#    Control_Range             Battery Type  Weight    Price  Actual_Price  \
# 0             40          Lithium Battery     200   2297.0        4999.0
# 1            300               AA Battery     500  10255.0       11000.0
# 2            102  AA Rechargeable Battery     150   1994.0        5999.0
# 3             50          Lithium Battery     150   2455.0        4999.0
# 4            200          Lithium Battery     200   4998.0        5999.0
#
#    Discount (%)
# 0          54.0
# 1           6.0
# 2          66.0
# 3          50.0
# ...

# %%
Product_data.select_dtypes(include = 'object').head()
# Out:
#                                                 name                type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#               Battery Type
# 0          Lithium Battery
# 1               AA Battery
# 2  AA Rechargeable Battery
# 3          Lithium Battery
# 4          Lithium Battery

# %%
Product_data.select_dtypes(exclude = 'object').head()
# Out:
#    Control_Range  Weight    Price  Actual_Price  Discount (%)
# 0             40     200   2297.0        4999.0          54.0
# 1            300     500  10255.0       11000.0           6.0
# 2            102     150   1994.0        5999.0          66.0
# 3             50     150   2455.0        4999.0          50.0
# 4            200     200   4998.0        5999.0          16.0

# %%
Categorical_col = Product_data.select_dtypes(include = 'object').columns
Categorical_col
# Out:
# Index(['name', 'type', 'Battery Type'], dtype='object')

# %%
Numerical_col = Product_data.select_dtypes(exclude = 'object').columns
Numerical_col
# Out:
# Index(['Control_Range', 'Weight', 'Price', 'Actual_Price', 'Discount (%)'], dtype='object')

# %%
Cat_df = Categorical_col = Product_data.select_dtypes(include = 'object')
Cat_df
# Out:
#                                                   name                type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#                 Battery Type
# 0            Lithium Battery
# ...

# %%
num_df = Categorical_col = Product_data.select_dtypes(exclude = 'object')
num_df
# Out:
#      Control_Range  Weight    Price  Actual_Price  Discount (%)
# 0               40     200   2297.0        4999.0          54.0
# 1              300     500  10255.0       11000.0           6.0
# 2              102     150   1994.0        5999.0          66.0
# 3               50     150   2455.0        4999.0          50.0
# 4              200     200   4998.0        5999.0          16.0
# ..             ...     ...      ...           ...           ...
# 816             60     250   2244.0        8999.0          75.0
# 817            100     350   2447.0        4999.0          51.0
# 818            102     400   1799.0        6999.0          74.0
# 819             60     250   2799.0        5999.0          53.0
# 820            100     300   2705.0        8999.0          69.0
#
# [821 rows x 5 columns]

# %%
Categorical_col_list = list(Product_data.select_dtypes(include = 'object').columns)
Categorical_col_list
# Out:
# ['name', 'type', 'Battery Type']

# %%
Numerical_col_list = list(Product_data.select_dtypes(exclude = 'object').columns)
Numerical_col_list
# Out:
# ['Control_Range', 'Weight', 'Price', 'Actual_Price', 'Discount (%)']

# %%
# checking the duplicate record
Product_data.duplicated().any()
# Out:
# np.True_

# %%
Product_data.duplicated().sum()
# Out:
# np.int64(3)

# %%
# display the deuplicate records
Product_data[Product_data.duplicated()]
# Out:
#                                                   name                type  \
# 478  Swa Mi E88 Pro Foldable Remote Control Drone D...  Professional Drone
# 609  Swa Mi Mini dron with Camera Hd Dual Camera Wi...  Professional Drone
# 630  Swa Mi High Quality E88 Pro Drone HD, Dual Cam...  Professional Drone
#
#      Control_Range     Battery Type  Weight   Price  Actual_Price  \
# 478            100  Lithium Battery     100  2705.0        8999.0
# 609            100  Lithium Battery     100  2244.0        8999.0
# 630            100  Lithium Battery     100  2705.0        8999.0
#
#      Discount (%)
# 478          69.0
# 609          75.0
# 630          69.0

# %%
Product_data2 = Product_data.drop_duplicates()

# %%
Product_data.shape
# Out:
# (821, 8)

# %%
Product_data2.duplicated().any()
# Out:
# np.False_

# %%
#iNDEXING  the columns
df = Product_data2.isnull().sum().reset_index()
#Rename the column
df.columns = ['column', 'null_records']
#Create the new columns and give out the null value percentage
df['% null_records'] = (df['null_records']/11199)*100
df
# Out:
#           column  null_records  % null_records
# 0           name             0        0.000000
# 1           type             0        0.000000
# 2  Control_Range             0        0.000000
# 3   Battery Type             0        0.000000
# 4         Weight             0        0.000000
# 5          Price             8        0.071435
# 6   Actual_Price             8        0.071435
# 7   Discount (%)            11        0.098223

# %%
Product_data.head(2)
# Out:
#                                                 name        type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...  Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...  Mini Drone
#
#    Control_Range     Battery Type  Weight    Price  Actual_Price  Discount (%)
# 0             40  Lithium Battery     200   2297.0        4999.0          54.0
# 1            300       AA Battery     500  10255.0       11000.0           6.0

# %%
# display the deuplicate records
Product_data[Product_data.duplicated()]
# Out:
#                                                   name                type  \
# 478  Swa Mi E88 Pro Foldable Remote Control Drone D...  Professional Drone
# 609  Swa Mi Mini dron with Camera Hd Dual Camera Wi...  Professional Drone
# 630  Swa Mi High Quality E88 Pro Drone HD, Dual Cam...  Professional Drone
#
#      Control_Range     Battery Type  Weight   Price  Actual_Price  \
# 478            100  Lithium Battery     100  2705.0        8999.0
# 609            100  Lithium Battery     100  2244.0        8999.0
# 630            100  Lithium Battery     100  2705.0        8999.0
#
#      Discount (%)
# 478          69.0
# 609          75.0
# 630          69.0

# %%
Product_data2 = Product_data.drop_duplicates()

# %%
Product_data2['name']
# Out:
# 0      Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...
# 1      Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...
# 2      Clubmall E88 Pro 4K Camera Drone with WiFi FPV...
# 3      Orivox A17 Aerial Drone with 4K Dual Camera - ...
# 4      Orivox M3 Max Mini Drone with Pro Features HD ...
#                              ...
# 816    Swa Mi Drone WiFi Camera Remote Control-Motion...
# 817                                Radhikadro e449 Drone
# 818    Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...
# 819    mayuri E8 WiFi Camera Remote Control 360 Flip ...
# 820    Swa Mi E88 Drone Best Adults/Kids Drone With W...
# Name: name, Length: 818, dtype: object

# %%
mode_name = Product_data2['name'].mode()[0]
mode_name
# Out:
# 'Swa Mi Drone WiFi Camera Drone Remote Control Quadcopter 360 Flip Stunt Drone1 Drone'

# %%
Product_data2['name'].value_counts()
# Out:
# name
# Swa Mi Drone WiFi Camera Drone Remote Control Quadcopter 360 Flip Stunt Drone1 Drone    7
# Swa Mi Drone WiFi Camera Remote Control Quadcopter 360 Flip Stunt Drone1 Drone          3
# Swa Mi Drone WiFi Camera Remote Control Quadcopter 360 Flip Stunt1 Drone                3
# Swa Mi Quadcopter E88 Drone With Wide Angle HD Camera Height Hold Foldable1 Drone       2
# Swa Mi E88 Pro Drone Wide Angle Dual 4K HD Cameras with two Smart battery1 Drone        2
#                                                                                        ..
# Barbie dronRemote Control Quadcopter 360 Flip Stunt_a8b Drone                           1
# Barbie E88-Drone - Black_5b Drone                                                       1
# Barbie Foldable Remote Control Drone with Camera HD Wide Angle Lens_18b Drone           1
# Barbie ad172drone3b Drone                                                               1
# ...

# %%
Product_data2['type'].value_counts()
# Out:
# type
# Professional Drone    427
# Mini Drone            391
# Name: count, dtype: int64

# %%
Product_data2['name'] = Product_data2['name'].fillna(mode_name)
# Out:
# /tmp/ipykernel_10086/2932877973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product_data2['name'] = Product_data2['name'].fillna(mode_name)

# %%
Product_data2.isnull().sum()
# Out:
# name              0
# type              0
# Control_Range     0
# Battery Type      0
# Weight            0
# Price             8
# Actual_Price      8
# Discount (%)     11
# dtype: int64

# %%
Price_mean = Product_data2['Price'].mean()
Product_data2['Price'] = Product_data2['Price'].fillna(Price_mean)
# Out:
# /tmp/ipykernel_10086/1959764243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product_data2['Price'] = Product_data2['Price'].fillna(Price_mean)

# %%
Product_data2.isnull().sum()
# Out:
# name              0
# type              0
# Control_Range     0
# Battery Type      0
# Weight            0
# Price             0
# Actual_Price      0
# Discount (%)     11
# Product           0
# dtype: int64

# %%
Actual_Price_mean = Product_data2['Actual_Price'].mean()
Product_data2['Actual_Price'] = Product_data2['Actual_Price'].fillna(Actual_Price_mean)
# Out:
# /tmp/ipykernel_10086/1905330224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product_data2['Actual_Price'] = Product_data2['Actual_Price'].fillna(Actual_Price_mean)

# %%
Product_data2.isnull().sum()
# Out:
# name              0
# type              0
# Control_Range     0
# Battery Type      0
# Weight            0
# Price             0
# Actual_Price      0
# Discount (%)     11
# Product           0
# dtype: int64

# %%
Discount_mean = Product_data2['Discount (%)'].mean()
Product_data2['Discount (%)'] = Product_data2['Discount (%)'].fillna(Discount_mean)
# Out:
# /tmp/ipykernel_10086/3477054433.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product_data2['Discount (%)'] = Product_data2['Discount (%)'].fillna(Discount_mean)

# %%
Product_data2.isnull().sum()
# Out:
# name             0
# type             0
# Control_Range    0
# Battery Type     0
# Weight           0
# Price            0
# Actual_Price     0
# Discount (%)     0
# Product          0
# dtype: int64
